# %%
# %run -i 'main.py'
# Out:
# Getting data from 'rekts' API endpoint:
# 100%|██████████| 66/66 [02:48<00:00,  2.55s/it]
# Processing: Abandoned
# Processing: Access Control
# Processing: Flash Loan Attack
# Processing: Honeypot
# Processing: Oracle Issue
# Processing: Other
# Processing: Phishing
# Processing: Reentrancy
# Processing: Rugpull
